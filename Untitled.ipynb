# %%
import os
import sys
import datetime
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import microprediction

# %%
from microprediction import new_key, MicroWriter, MicroReader

# %%
write_key = new_key(difficulty=9)

# %%
from microprediction import MicroReader
mr = MicroReader()
stream = 
current_value = mr.get('c5_iota.json')
lagged_values = mr.get_lagged_values('c5_iota.json') 
lagged_times  = mr.get_lagged_times('c5_iota.json')

# %%
dir(mr)
# Out:
# ['BACKLINKS',
#  'BALANCE',
#  'BUDGETS',
#  'CDF',
#  'CONFIRMS',
#  'CUSTOM_LEADERBOARD',
#  'DELAYED',
#  'DELAYS',
#  'ERRORS',
#  'HISTORY',
#  'LAGGED',
#  'LAGGED_TIMES',
#  'LAGGED_VALUES',
#  'LEADERBOARD',
#  'LINKS',
#  'MESSAGES',
#  'PERFORMANCE',
#  'PREDICTIONS',
#  'SAMPLES',
#  'SEP',
#  'SUBSCRIBERS',
#  'SUBSCRIPTIONS',
#  'SUMMARY',
#  'TILDE',
#  'TRANSACTIONS',
#  'VOLUMES',
#  'WARNINGS',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cdf_continuous_values',
#  '_cdf_discrete_values',
#  '_get_cdf',
#  '_normcdf_function',
#  '_norminv_function',
#  'animal_from_code',
# ...

# %%
mr.get_stream_names()
# Out:
# ['emojitracker-twitter-face_throwing_a_kiss.json',
#  'z1~airport-ewr-economy_parking_p6~3555.json',
#  'z1~electricity-lbmp-nyiso-north~3555.json',
#  'emojitracker-twitter-eyes.json',
#  'z1~traffic-nj511-minutes-nj_495_from_the_nj_turnpike_to_the_ny_side_via_the_south_tube~70.json',
#  'z1~traffic-nj511-minutes-nj_turnpike_exit_14_to_nj_turnpike_exit_8a~70.json',
#  'traffic-nj511-minutes-route_4_from_fort_lee_to_the_alexander_hamilton_bridge_via_the_lower_level.json',
#  'z1~airport-ewr-security-wait-terminal_b_60-68_reg~70.json',
#  'z1~airport-ewr-security-wait-terminal_a_30-39_tsapre~70.json',
#  'ginj-intraday-tactical-asset-allocation-energy.json',
#  'z1~emojitracker-twitter-fire~3555.json',
#  'traffic-nj511-minutes-ny_side_to_nj_turnpike_exit_14c.json',
#  'ginj-intraday-tactical-asset-allocation-energy-mean.json',
#  'z1~emojitracker-twitter-thumbs_up_sign~70.json',
#  'z1~traffic-nj511-minutes-i-95_from_i-80_to_the_alexander_hamilton_bridge_via_upper_level~70.json',
# ...
